# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import csv
import os
from osgeo import ogr
import pyproj
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
scoredata = pd.read_csv('London/school/2sfca_30min.csv')
gdf = gpd.read_file(f"zip://statistical-gis-boundaries-london.zip!statistical-gis-boundaries-london/ESRI/London_Ward.shp").to_crs("EPSG:4326")
testscore = pd.merge(gdf,scoredata,left_on='GSS_CODE', right_on='GSS_CODE', how='outer').reset_index()
base=testscore.plot(column="score", cmap="RdPu" , figsize=(12,24))

# %%
scoredata = pd.read_csv('shanghai/school/2sfca_60min.csv')
gdf = gpd.read_file("shanghai_shp/shanghai1.shp").to_crs("EPSG:4326")
testscore = pd.merge(gdf,scoredata,left_on='NAME', right_on='NAME', how='outer').reset_index()
base=testscore.plot(column="score", cmap="RdPu" , figsize=(12,24))

# %%
fig, ax = plt.subplots(figsize=(20,24))
ax.set_aspect('equal')

scoredata = pd.read_csv('Shanghai/hospital/gbm_raised_cosine_1800.csv')
gdf = gpd.read_file("shanghai_shp/shanghai1.shp").to_crs("EPSG:4326")
testscore = pd.merge(gdf,scoredata,left_on='NAME', right_on='NAME', how='outer').reset_index()


testscore.plot(ax=ax,column="score",alpha=0.9, cmap="YlGnBu")
gdf.boundary.plot( ax=ax,color="black",edgecolor='black')

plt.show()
